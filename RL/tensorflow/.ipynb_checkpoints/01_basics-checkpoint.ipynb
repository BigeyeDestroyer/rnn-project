# %%
# !source activate tensorflow
# Out:
# discarding /Users/ray/anaconda/bin from PATH
# prepending /Users/ray/anaconda/envs/tensorflow/bin to PATH

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# tf.Graph represents a collection of tf.Operations
# You can create operations by writing out equations.
# By default, there is a graph: tf.get_default_graph()
# and any new operations are added to this graph.
# The result of a tf.Operation is a tf.Tensor, which holds
# the values.

# %%
# %% First a tf.Tensor
n_values = 32
x = tf.linspace(-3.0, 3.0, n_values)

# %%
# %% method 1: Construct a tf.Session to execute the graph 
sess = tf.Session()
result = sess.run(x)

# %%
# %% method 2: Alternatively pass a session to the eval fn
x.eval(session=sess)
# x.eval() does not work, as it requires a session!
# Out:
# array([-3.        , -2.80645156, -2.61290312, -2.41935492, -2.22580647,
#        -2.03225803, -1.83870971, -1.64516139, -1.45161295, -1.25806451,
#        -1.06451619, -0.87096786, -0.67741942, -0.48387098, -0.29032278,
#        -0.09677434,  0.0967741 ,  0.29032254,  0.48387098,  0.67741919,
#         0.87096763,  1.06451607,  1.25806427,  1.45161295,  1.64516115,
#         1.83870935,  2.03225803,  2.22580624,  2.41935444,  2.61290312,
#         2.80645132,  3.        ], dtype=float32)

# %%
# %% We can setup an interactive session if we don't 
# want to keep passing the session around:
sess.close()
sess = tf.InteractiveSession()

# %%
# %% Now this will work!
x.eval()
# Out:
# array([-3.        , -2.80645156, -2.61290312, -2.41935492, -2.22580647,
#        -2.03225803, -1.83870971, -1.64516139, -1.45161295, -1.25806451,
#        -1.06451619, -0.87096786, -0.67741942, -0.48387098, -0.29032278,
#        -0.09677434,  0.0967741 ,  0.29032254,  0.48387098,  0.67741919,
#         0.87096763,  1.06451607,  1.25806427,  1.45161295,  1.64516115,
#         1.83870935,  2.03225803,  2.22580624,  2.41935444,  2.61290312,
#         2.80645132,  3.        ], dtype=float32)

# %%
# %% Now a tf.Operation
# We'll use our values from [-3, 3] to create a Gaussian Distribution 
sigma = 1.0
mean = 0.0
z = (tf.exp(tf.neg(tf.pow(x - mean, 2.0) / 
                  (2.0 * tf.pow(sigma, 2.0)))) * 
    (1.0 / (sigma * tf.sqrt(2.0 * 3.1415))))

# %%
# %% By default, new operations are added to the default Graph
assert z.graph is tf.get_default_graph()

# %%
# %% Execute the graph and plot the result
plt.plot(z.eval())

# %%
# %% We can find out the shape of a tensor like so:
print(z.get_shape())
# Out:
# (32,)

# %%
# %% Or in a more friendly format
print(z.get_shape().as_list())
# Out:
# [32]

# %%
# %% Sometimes we may not know the shape of a tensor 
# until it is computed in the graph. In that case
# we should use the tf.shape fn, which will return a 
# Tensor which can be eval'ed, rather than a discrete
# value of tf.Dimension 
print(tf.shape(z).eval())
# Out:
# [32]

# %%
# %% We can combine tensors like so:
print(tf.pack([tf.shape(z), tf.shape(z), [3], [4]]).eval())
# Out:
# [[32]
#  [32]
#  [ 3]
#  [ 4]]

# %%
# %% Let's multiply the two to get a 2d gaussian 
z_2d = tf.matmul(tf.reshape(z, [n_values, 1]), tf.reshape(z, [1, n_values]))

# %%
# %% Execute the graph and store the value that 'out' represents in 'result'.
plt.imshow(z_2d.eval())

# %%
# %% For fun, let's create a gabor patch:
x = tf.reshape(tf.sin(tf.linspace(-3.0, 3.0, n_values)), [n_values, 1])
y = tf.reshape(tf.ones_like(x), [1, n_values])
z = tf.mul(tf.matmul(x, y), z_2d)
plt.imshow(z.eval())

# %%
# %% We can also list all the operations of a graph:
ops = tf.get_default_graph().get_operations()
print([op.name for op in ops])
# Out:
# [u'LinSpace/start', u'LinSpace/stop', u'LinSpace/num', u'LinSpace', u'sub/y', u'sub', u'Pow/y', u'Pow', u'Pow_1/x', u'Pow_1/y', u'Pow_1', u'mul/x', u'mul', u'div', u'Neg', u'Exp', u'Sqrt/x', u'Sqrt', u'mul_1/x', u'mul_1', u'div_1/x', u'div_1', u'mul_2', u'Shape', u'Shape_1', u'Shape_2', u'Shape_3', u'Shape_4', u'pack/values_2', u'pack/values_3', u'pack', u'Shape_5', u'Shape_6', u'pack_1/values_2', u'pack_1/values_3', u'pack_1', u'Shape_7', u'Shape_8', u'pack_2/values_2', u'pack_2/values_3', u'pack_2', u'Shape_9', u'Shape_10', u'Shape_11', u'Reshape/shape', u'Reshape', u'Shape_12', u'Reshape_1/shape', u'Reshape_1', u'Reshape_2/shape', u'Reshape_2', u'MatMul', u'Shape_13', u'LinSpace_1/start', u'LinSpace_2/start', u'LinSpace_2/stop', u'LinSpace_2/num', u'LinSpace_2', u'Reshape_3/shape', u'Reshape_3', u'Reshape_4/shape', u'Reshape_4', u'Reshape_5/shape', u'Reshape_5', u'MatMul_1', u'LinSpace_3/start', u'LinSpace_3/stop', u'LinSpace_3/num', u'LinSpace_3', u'Sin', u'Reshape_6/shape', u'Reshape_6', u'ones_like/Shape', u'ones_like/Const', u'ones_like', u'Reshape_7/shape', u'Reshape_7', u'MatMul_2', u'LinSpace_4/start', u'LinSpace_4/stop', u'LinSpace_4/num', u'LinSpace_4', u'LinSpace_5/start', u'LinSpace_5/stop', u'LinSpace_5/num', u'LinSpace_5', u'LinSpace_6/start', u'LinSpace_6/stop', u'LinSpace_6/num', u'LinSpace_6', u'LinSpace_7/start', u'LinSpace_7/stop', u'LinSpace_7/num', u'LinSpace_7', u'Mul', u'LinSpace_8/start', u'LinSpace_8/stop', u'LinSpace_8/num', u'LinSpace_8', u'LinSpace_9/start', u'LinSpace_9/stop', u'LinSpace_9/num', u'LinSpace_9', u'LinSpace_10/start', u'LinSpace_10/stop', u'LinSpace_10/num', u'LinSpace_10', u'Sin_1', u'Reshape_8/shape', u'Reshape_8', u'ones_like_1/Shape', u'ones_like_1/Const', u'ones_like_1', u'Reshape_9/shape', u'Reshape_9', u'MatMul_4', u'Mul_1']

# %%
# %% Let's try creating a generic function for computing the same thing
def gabor(n_values=32, sigma=1.0, mean=0.0):
    x = tf.linspace(-3.0, 3.0, n_values)
    z = (tf.exp(tf.neg(tf.pow(x - mean, 2.0) / 
                      (2.0 * tf.pow(sigma, 2.0)))) * 
         (1.0 / (sigma * tf.sqrt(2.0 * 3.1415))))
    gaussian_kernel = tf.matmul(
        tf.reshape(z, [n_values, 1]), tf.reshape(z, [1, n_values]))
    x = tf.reshape(tf.sin(tf.linspace(-3.0, 3.0, n_values)), [n_values, 1])
    y = tf.reshape(tf.ones_like(x), [1, n_values])
    gabor_kernel = tf.mul(tf.matmul(x, y), gaussian_kernel)
    return gabor_kernel

# %%
# %% Confirm this does something:
plt.imshow(gabor().eval())

# %%
# %% And another function which can convolve
def convolve(img, W):
    # The W matrix is only 2D 
    # But conv2d will need a tensor which is 4d:
    # height x width x n_input x n_output 
    if len(W.get_shape()) == 2:
        dims = W.get_shape().as_list() + [1, 1]
        W = tf.reshape(W, dims)
        
    if len(img.get_shape()) == 2:
        # num x height x width x channels 
        dims = [1] + img.get_shape().as_list() + [1]
        img = tf.reshape(img, dims)
    elif len(img.get_shape()) == 3:
        dims = [1] + img.get_shape().as_list()
        img = tf.reshape(img, dims)
        # if the image is 3 channels, then our convolution
        # kernel needs to be repeated for each input channel
        # original size of W is: height x width x 1 x 1
        # after concatenation: height x widht x 3 x 1
        W = tf.concat(2, [W, W, W])
        
    # We have 'SAME' and 'VALID' for padding
    # 'SAME'  : return w_img
    # 'VALID' : return w_img - w_kernel + 1
    convolved = tf.nn.conv2d(img, W, strides=[1, 1, 1, 1],
                            padding='SAME')
    return convolved

# %%
# %% Load up an image:
from skimage import data
img = data.astronaut()
plt.imshow(img)
print(img.shape)
# Out:
# (512, 512, 3)

# %%
# %% Now create a placeholder for our graph which can store any input:
x = tf.placeholder(tf.float32, shape=img.shape)

# %%
# %% And a graph which can convolve our image with a gabor
out = convolve(x, gabor())
print(gabor().eval().shape)
# Out:
# (32, 32)

# %%
# %% Now send the image into the graph and compute the result
result = tf.squeeze(out).eval(feed_dict={x:img})
plt.imshow(result)
print(result.shape)
# Out:
# (512, 512)
